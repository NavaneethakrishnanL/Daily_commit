# %%
# Convert a string to title case
def to_title_case(s):
    return s.title()

# Example usage
result = to_title_case("welcome to python")
print(result)
# Input: "welcome to python" → Output: "Welcome To Python"
# Out:
# Welcome To Python
